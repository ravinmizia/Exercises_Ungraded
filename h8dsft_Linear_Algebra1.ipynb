# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

asd

# %%
z = [17,22,19]

# %% [markdown]
# asd

# %%
vector_z = np.array(a)
vector_a = np.array([17,22,19]) 
vector_b = np.array ([10,20,11])
vector_c = np.array ([5,12,9])

# %%
print( vector_a * vector_b)
print( vector_a - vector_b)
print(vector_c @ vector_a)
print(np.linalg.norm(vector_a))
# Out:
# [170 440 209]
# [7 2 8]
# 520
# 33.67491648096547

# %%
cos_theta = (vector_a @ vector_b) / (np.linalg.norm(vector_b) * np.linalg.norm(vector_b))

# %%
cos_theta
# Out:
# 1.3188405797101452

# %%
Vecs = np.array([[17,22,19],[10,20,11],[5,12,9],vector_z])
null_vector = np.array([[0, 0, 0]]) # origin point

A,B,C,Z = zip(Vecs)

plt.quiver(null_vector,A,B,C,Z,angles='xy',scale_units='xy', scale=5)
plt.ylim([0,50])
plt.xlim([0,50])
# Out:
# (0.0, 50.0)

# %%
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_63716\3493158389.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   soa = np.array([[np.x1[0]],[np.y1[0]],[np.x2[0]], np.y2[0]])

# %%
import sympy as sy
import numpy as np
x = np.linspace(0,20)
y = 2*x**2+4*x-1
df=np.gradient(y,x)
df
# Out:
# array([ 4.81632653,  5.63265306,  7.26530612,  8.89795918, 10.53061224,
#        12.16326531, 13.79591837, 15.42857143, 17.06122449, 18.69387755,
#        20.32653061, 21.95918367, 23.59183673, 25.2244898 , 26.85714286,
#        28.48979592, 30.12244898, 31.75510204, 33.3877551 , 35.02040816,
#        36.65306122, 38.28571429, 39.91836735, 41.55102041, 43.18367347,
#        44.81632653, 46.44897959, 48.08163265, 49.71428571, 51.34693878,
#        52.97959184, 54.6122449 , 56.24489796, 57.87755102, 59.51020408,
#        61.14285714, 62.7755102 , 64.40816327, 66.04081633, 67.67346939,
#        69.30612245, 70.93877551, 72.57142857, 74.20408163, 75.83673469,
#        77.46938776, 79.10204082, 80.73469388, 82.36734694, 83.18367347])

# %%
from scipy.optimize import minimize_scalar

# %%
def f(x):
    return 2*x**2+4*x-1

opt=minimize_scalar(f)
opt
# Out:
#      fun: -3.0
#  message: '\nOptimization terminated successfully;\nThe returned value satisfies the termination criteria\n(using xtol = 1.48e-08 )'
#     nfev: 9
#      nit: 4
#  success: True
#        x: -1.0000000000000002
